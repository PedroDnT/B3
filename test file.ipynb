# %%
from B3_Reader import *

file = "/Users/pedrotodescan/projects data/Cotacoes_Hist/COTAHIST_A2006.TXT" 

dataFY06 = parse_dataset(file)
dataFY06 = translate_bdi(dataFY06)
dataFY06 = market_type(dataFY06)
dataFY06 = price_mod(dataFY06)
dataFY06 = set_numerics(dataFY06)

# %%
dataFY06.head()
# Out:
#         Date              BDICode  Ticker   MarketType FirmName  Especs  \
# 0 2006-01-02          LOTE PADRAO   ACES4        VISTA  ACESITA  PN  EJ
# 1 2006-01-02  MERCADO FRACIONARIO  ACES4F  FRACIONARIO  ACESITA  PN  EJ
# 2 2006-01-02      MERCADO A TERMO  ACES4T        TERMO  ACESITA  PN  EJ
# 3 2006-01-02      MERCADO A TERMO  ACES4T        TERMO  ACESITA  PN  EJ
# 4 2006-01-02      MERCADO A TERMO  ACES4T        TERMO  ACESITA  PN  EJ
#
#    DaysDue(fut) Currency  OpenPrice  HighPrice      ...       BestBid  \
# 0           NaN       R$      28.45      28.65      ...         28.45
# 1           NaN       R$      28.85      28.85      ...         28.60
# 2          16.0       R$      28.79      28.80      ...          0.00
# 3          30.0       R$      28.84      28.88      ...          0.00
# 4          60.0       R$      28.84      28.85      ...          0.00
#
#    BestAsk  #Trades  #BondTrades      Volume  ExecutionPrice(Futures)  Adjust  \
# 0    28.65      168        74100  2096535.00                      0.0       0
# 1    28.69       31         1022    29147.18                      0.0       0
# 2     0.00        2          100     2879.58                      0.0       0
# 3     0.00        6         5100   146363.92                      0.0       0
# 4     0.00        2          500    14420.84                      0.0       0
#
#    ExpiringDate  LoteSize      IsinCode
# 0           NaT         1  BRACESACNPR2
# 1           NaT         1  BRACESACNPR2
# 2           NaT         1  BRACESACNPR2
# 3           NaT         1  BRACESACNPR2
# 4           NaT         1  BRACESACNPR2
#
# [5 rows x 23 columns]
